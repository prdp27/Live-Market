# %%
import pandas as pd

df_live = pd.read_csv("D:\\prdp\\Data Analytics\\Live-Market\\Live-Market - Copy.csv")
df_live.sample(5)
# Out:
#              DMD-DateTime    DMD-Date  DMD-Day  DMD-Month  DMD-Year  DMH-Time  \
# 7408  05-01-2012 00:00:00  2012-01-05        5          1      2012  00:00:00
# 9920  23-02-2022 00:00:00  2022-02-23       23          2      2022  00:00:00
# 6252  09-05-2007 00:00:00  2007-05-09        9          5      2007  00:00:00
# 8748  02-06-2017 00:00:00  2017-06-02        2          6      2017  00:00:00
# 7275  22-06-2011 00:00:00  2011-06-22       22          6      2011  00:00:00
#
#       DMH-Hours-24  DMH-Minutes DMT-Month_Name DMT-Day_Name  ...      DMT-FY  \
# 7408             0            0            Jan          Thu  ...  FY 2011-12
# 9920             0            0            Feb          Wed  ...  FY 2021-22
# 6252             0            0            May          Wed  ...  FY 2007-08
# 8748             0            0            Jun          Fri  ...  FY 2017-18
# 7275             0            0            Jun          Wed  ...  FY 2011-12
#
# ...

# %%
df_silv = pd.read_csv("D:\\prdp\\Data Analytics\\Live-Market\\Silver EFT Historical Data.csv")
df_silv = df_silv[["Date", "SilverETF"]]
df_silv.sample(5)
# Out:
#             Date  SilverETF
# 1070  11-02-2022      62.36
# 478   05-07-2024      88.68
# 16    19-05-2026     253.25
# 79    11-02-2026     247.37
# 43    08-04-2026     230.58

# %%
df = df_live.join(df_silv, how="left")
df
# Out:
#               DMD-DateTime    DMD-Date  DMD-Day  DMD-Month  DMD-Year  \
# 0      03-04-1979 00:00:00  1979-04-03        3          4      1979
# 1      04-04-1979 00:00:00  1979-04-04        4          4      1979
# 2      06-04-1979 00:00:00  1979-04-06        6          4      1979
# 3      07-04-1979 00:00:00  1979-04-07        7          4      1979
# 4      09-04-1979 00:00:00  1979-04-09        9          4      1979
# ...                    ...         ...      ...        ...       ...
# 14663  11-06-2026 13:42:48  11-06-2026       11          6      2026
# 14664  11-06-2026 13:47:49  11-06-2026       11          6      2026
# 14665  11-06-2026 13:52:50  11-06-2026       11          6      2026
# 14666  11-06-2026 13:57:52  11-06-2026       11          6      2026
# 14667  11-06-2026 14:02:53  11-06-2026       11          6      2026
#
#        DMH-Time  DMH-Hours-24  DMH-Minutes DMT-Month_Name DMT-Day_Name  ...  \
# ...
